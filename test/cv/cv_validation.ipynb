# %% [markdown]
# This notebook  demonstrates the use of new SHACL shapes for controlled vocabularies in a validation process. The SHACL shapes used in this demonstration conform to the [solution specification](https://github.com/OP-TED/model2owl/issues/228#issuecomment-2557009873) and the [model2owl documentation](https://meaningfy-ws.github.io/model2owl-docs-gh-pages). The notebook uses real ([EU vocabularies](https://op.europa.eu/en/web/eu-vocabularies/e-procurement/tables)) and crafted vocabularies to test both valid and invalid setups for both _permissive_ and _restrictive_ [constraint levels](https://meaningfy-ws.github.io/model2owl-docs-gh-pages/public-review/uml/conv-enumerations.html#rule:enumeration-constraint-level).
#
# The generation of SHACL shapes using model2owl and testing them is beyond the scope of this notebook as this is already covered by model2owl test suite. However, the notebook relies on SHACL shapes in the same form as those generated by model2owl.
#
# A minimal, crafted dataset of RDF resources is used, aligned with the [ePO ontology](https://github.com/OP-TED/ePO), to demonstrate the application of constraints implemented in the SHACL shapes.

# %%
# install required packages
! pip install pyshacl
! pip install rdflib

# %%
from pathlib import Path
from pyshacl import validate
import rdflib

# %%
CWD = Path().resolve()
TESTS_PATH = Path(CWD).parent.resolve()
DATA_DIR = TESTS_PATH / "testData" / "noticeData"
CV_DATA_DIR = TESTS_PATH / "testData" / "cv"
SHAPES_DATA_PATH = TESTS_PATH / "testData" / "shacl" / "cv-shapes.ttl"

# %% [markdown]
# **Note**: Set the variable below to _True_ to enable printing of extra information

# %%
VERBOSE = True

# %% [markdown]
# Define helper functions

# %%
def load(one_or_more_rdf_files: Path | tuple[Path] | list[Path]) -> rdflib.Graph:
    graph = rdflib.Graph()
    files = (
        [one_or_more_rdf_files] if isinstance(one_or_more_rdf_files, Path) else one_or_more_rdf_files
    )
    for f in files:
        graph.parse(f)
    return graph


def run_validation(data_graph: rdflib.Graph, shacl_shape_graph: rdflib.Graph):
    return validate(
        data_graph,
        shacl_graph=shacl_shape_graph,
        meta_shacl=False,
        js=False,
        debug=False,
    )

# %% [markdown]
# Define test cases for permissive and restrictive constraint levels together with the expected validation result

# %%
cases = (
    # (description, rdf_data, validation_result)
    (
        "01: permissive shape for hasReservedExecution with at-voc:applicability concept",
        ((DATA_DIR / "data01.ttl", CV_DATA_DIR / "applicability-skos.rdf"), SHAPES_DATA_PATH),
        True,
    ),
    (
        "02: permissive shape for hasReservedExecution with an arbitrary concept",
        ((DATA_DIR / "data02.ttl", CV_DATA_DIR / "dummy-concepts.ttl"), SHAPES_DATA_PATH),
        True,
    ),
    (
        "03: validation using restrictive shape for hasEInvoicingPermission with a concept belonging to at-voc:permission",
        ((DATA_DIR / "data03.ttl", CV_DATA_DIR / "permission-skos.rdf"), SHAPES_DATA_PATH),
        True,
    ),
    (
        "04: validation using restrictive shape for hasContractNatureType with a concept belonging to an arbitrary scheme fails",
        ((DATA_DIR / "data04.ttl", CV_DATA_DIR / "dummy-concepts.ttl"), SHAPES_DATA_PATH),
        False,
    ),
    (
        "05: validation using permissive shape for hasReservedExecution with an arbitrary resource fails",
        ((DATA_DIR / "data05.ttl", CV_DATA_DIR / "dummy-concepts.ttl"), SHAPES_DATA_PATH),
        False,
    ),
)

# %% [markdown]
# Run tests for the defined cases

# %%
for case_descr, input_data, expected in cases:
    if VERBOSE:
        print(f"*** case {case_descr} ***")
    data_files, shapes_files = input_data
    data_graph = load(data_files)
    shapes_graph = load(shapes_files)
    if VERBOSE:
        print("Data graph:")
        print(data_graph.serialize(format="ttl"))
        print("Shapes graph:")
        print(shapes_graph.serialize(format="ttl"))
    conforms, results_graph, results_text = run_validation(
        data_graph,
        shapes_graph,
    )
    if VERBOSE:
        print(results_text)
    assert conforms == expected, f"'{case_descr}' failed."
# Out:
# *** case 01: permissive shape for hasReservedExecution with at-voc:applicability concept ***
# Data graph:
# @prefix at: <http://publications.europa.eu/ontology/authority/> .
# @prefix atold: <http://publications.europa.eu/resource/authority/> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix epd: <http://data.europa.eu/a4g/resource/> .
# @prefix epo: <http://data.europa.eu/a4g/ontology#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# epd:ContractTerm01 a epo:ContractTerm ;
#     epo:hasReservedExecution <http://publications.europa.eu/resource/authority/applicability/no> .
#
# <http://publications.europa.eu/resource/authority/applicability/OP_DATPRO> a skos:Concept ;
#     at:authority-code "OP_DATPRO" ;
#     at:deprecated "true" ;
#     at:end.use "1952-07-24" ;
#     at:op-code "OP_DATPRO" ;
#     at:start.use "1952-07-23" ;
#     atold:op-code "OP_DATPRO" ;
#     dc:identifier "OP_DATPRO" ;
#     owl:deprecated true ;
#     skos:inScheme atold:applicability ;
#     skos:prefLabel "Неокончателни данни"@bg,
#         "Předběžné údaje"@cs,
#         "Midlertidige data"@da,
#         "Vorläufige Daten"@de,
#         "Προσωρινά δεδομένα"@el,
#         "Provisional data"@en,
#         "Datos provisionales"@es,
#         "Esialgsed andmed"@et,
#         "Alustavat tiedot"@fi,
#         "Données provisoires"@fr,
#         "Sonraí sealadacha"@ga,
#         "Privremeni podaci"@hr,
#         "Ideiglenes adatok"@hu,
#         "Dati provvisori"@it,
#         "Laikinieji duomenys"@lt,
#         "Provizoriski dati"@lv,
#         "Dejta provviżorja"@mt,
#         "Voorlopige gegevens"@nl,
#         "Dane tymczasowe"@pl,
#         "Dados provisórios"@pt,
#         "Date provizorii"@ro,
#         "Predbežné údaje"@sk,
#         "Začasni podatki"@sl,
#         "Tillfälliga uppgifter"@sv ;
#     skos:topConceptOf atold:applicability .
#
# <http://publications.europa.eu/resource/authority/applicability/not-known> a skos:Concept ;
#     at:authority-code "not-known" ;
#     at:deprecated "false" ;
#     at:op-code "not-known" ;
#     at:start.use "2019-09-18" ;
#     atold:op-code "not-known" ;
#     dc:identifier "not-known" ;
#     skos:altLabel "Ännu ej känd"@sv ;
#     skos:inScheme atold:applicability ;
#     skos:prefLabel "Все още не е известно"@bg,
#         "Není známo"@cs,
#         "Endnu ikke kendte"@da,
#         "Noch nicht bekannt"@de,
#         "Δεν έχει ακόμη προσδιοριστεί"@el,
#         "Not yet known"@en,
#         "No se sabe aún"@es,
#         "Ei ole veel teada"@et,
#         "Ei vielä tiedossa"@fi,
#         "Pas encore connu"@fr,
#         "Ní fios go fóill"@ga,
#         "Još nije poznato"@hr,
#         "Jelenleg ismeretlen"@hu,
#         "Non ancora noto"@it,
#         "Dar nežinoma"@lt,
#         "Vēl nav zināms"@lv,
#         "Għadu mhux magħruf"@mt,
#         "Nog niet bekend"@nl,
#         "Jeszcze nie wiadomo"@pl,
#         "Ainda não conhecido"@pt,
#         "Nu se știe încă"@ro,
#         "Použitie zatiaľ nie je známe"@sk,
#         "Še ni znano"@sl,
#         "Ännu ej känt"@sv ;
#     skos:topConceptOf atold:applicability .
#
# <http://publications.europa.eu/resource/authority/applicability/yes> a skos:Concept ;
#     at:authority-code "yes" ;
#     at:deprecated "false" ;
#     at:op-code "yes" ;
#     at:start.use "2019-09-18" ;
#     atold:op-code "yes" ;
#     dc:identifier "yes" ;
#     skos:inScheme atold:applicability ;
#     skos:prefLabel "Да"@bg,
#         "Ano"@cs,
#         "Ja"@da,
#         "Ja"@de,
#         "Ναι"@el,
#         "Yes"@en,
#         "Sí"@es,
#         "Jah"@et,
#         "Kyllä"@fi,
#         "Oui"@fr,
#         "Is ea"@ga,
#         "Da"@hr,
#         "Igen"@hu,
#         "Sì"@it,
#         "Taip"@lt,
#         "Jā"@lv,
#         "Iva"@mt,
#         "Ja"@nl,
#         "Tak"@pl,
#         "Sim"@pt,
#         "Da"@ro,
#         "Áno"@sk,
#         "Da"@sl,
#         "Ja"@sv ;
#     skos:topConceptOf atold:applicability .
#
# <http://publications.europa.eu/resource/authority/applicability/no> a skos:Concept ;
#     at:authority-code "no" ;
#     at:deprecated "false" ;
#     at:op-code "no" ;
#     at:start.use "2019-09-18" ;
#     atold:op-code "no" ;
#     dc:identifier "no" ;
#     skos:inScheme atold:applicability ;
#     skos:prefLabel "Не"@bg,
#         "Ne"@cs,
#         "Nej"@da,
#         "Nein"@de,
#         "Όχι"@el,
#         "No"@en,
#         "No"@es,
#         "Ei"@et,
#         "Ei"@fi,
#         "Non"@fr,
#         "Ní hea"@ga,
#         "Ne"@hr,
#         "Nem"@hu,
#         "No"@it,
#         "Ne"@lt,
#         "Nē"@lv,
#         "Le"@mt,
#         "Neen"@nl,
#         "Nie"@pl,
#         "Não"@pt,
#         "Nu"@ro,
#         "Nie"@sk,
#         "Ne"@sl,
#         "Nej"@sv ;
#     skos:topConceptOf atold:applicability .
#
# atold:applicability a skos:ConceptScheme ;
#     rdfs:label "Applicability"@en ;
#     at:prefLabel "Applicability"@en ;
#     at:table.id "applicability" ;
#     at:table.version.number "20240612-0" ;
#     owl:versionInfo "20240612-0" ;
#     skos:hasTopConcept <http://publications.europa.eu/resource/authority/applicability/OP_DATPRO>,
#         <http://publications.europa.eu/resource/authority/applicability/no>,
#         <http://publications.europa.eu/resource/authority/applicability/not-known>,
#         <http://publications.europa.eu/resource/authority/applicability/yes> ;
#     skos:prefLabel "Applicability"@en .
#
#
# Shapes graph:
# @prefix : <http://data.europa.eu/a4g/ontology#> .
# @prefix at-voc: <http://publications.europa.eu/resource/authority/> .
# @prefix core-shape: <http://data.europa.eu/a4g/data-shape#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# core-shape:epo-ContractTerm a sh:NodeShape ;
#     rdfs:label "Contract Term" ;
#     rdfs:comment "Conditions and stipulations defining particularities of the Post Award Phase." ;
#     rdfs:isDefinedBy core-shape:core-shape ;
#     sh:property core-shape:epo-ContractTerm-epo-hasContractNatureType,
#         core-shape:epo-ContractTerm-epo-hasEInvoicingPermission,
#         core-shape:epo-ContractTerm-epo-hasReservedExecution ;
#     sh:targetClass :ContractTerm .
#
# core-shape:at-voc-contract-nature-itemShape a sh:NodeShape ;
#     sh:property [ sh:hasValue at-voc:contract-nature ;
#             sh:path skos:inScheme ] .
#
# core-shape:at-voc-permission-itemShape a sh:NodeShape ;
#     sh:property [ sh:hasValue at-voc:permission ;
#             sh:path skos:inScheme ] .
#
# core-shape:epo-ContractTerm-epo-hasContractNatureType a sh:PropertyShape ;
#     sh:name "has Contract Nature Type" ;
#     sh:node core-shape:at-voc-contract-nature-itemShape ;
#     sh:path :hasContractNatureType .
#
# core-shape:epo-ContractTerm-epo-hasEInvoicingPermission a sh:PropertyShape ;
#     sh:name "has E Invoicing Permission" ;
#     sh:node core-shape:at-voc-permission-itemShape ;
#     sh:path :hasEInvoicingPermission .
#
# core-shape:epo-ContractTerm-epo-hasReservedExecution a sh:PropertyShape ;
#     sh:class skos:Concept ;
#     sh:maxCount 1 ;
#     sh:name "has Reserved Execution" ;
#     sh:path :hasReservedExecution .
#
#
# Validation Report
# Conforms: True
#
# *** case 02: permissive shape for hasReservedExecution with an arbitrary concept ***
# Data graph:
# @prefix : <http://example.com/> .
# @prefix epd: <http://data.europa.eu/a4g/resource/> .
# @prefix epo: <http://data.europa.eu/a4g/ontology#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
#
# epd:ContractTerm02 a epo:ContractTerm ;
#     epo:hasReservedExecution :no .
#
# :contractNature a skos:ConceptScheme ;
#     skos:hasTopConcept :services ;
#     skos:prefLabel "contract nature"@en .
#
# :yes skos:prefLabel "yes" .
#
# :no a skos:Concept .
#
# :services a skos:Concept .
#
#
# Shapes graph:
# @prefix : <http://data.europa.eu/a4g/ontology#> .
# @prefix at-voc: <http://publications.europa.eu/resource/authority/> .
# @prefix core-shape: <http://data.europa.eu/a4g/data-shape#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# core-shape:epo-ContractTerm a sh:NodeShape ;
#     rdfs:label "Contract Term" ;
#     rdfs:comment "Conditions and stipulations defining particularities of the Post Award Phase." ;
#     rdfs:isDefinedBy core-shape:core-shape ;
#     sh:property core-shape:epo-ContractTerm-epo-hasContractNatureType,
#         core-shape:epo-ContractTerm-epo-hasEInvoicingPermission,
#         core-shape:epo-ContractTerm-epo-hasReservedExecution ;
#     sh:targetClass :ContractTerm .
#
# core-shape:at-voc-contract-nature-itemShape a sh:NodeShape ;
#     sh:property [ sh:hasValue at-voc:contract-nature ;
#             sh:path skos:inScheme ] .
#
# core-shape:at-voc-permission-itemShape a sh:NodeShape ;
#     sh:property [ sh:hasValue at-voc:permission ;
#             sh:path skos:inScheme ] .
#
# core-shape:epo-ContractTerm-epo-hasContractNatureType a sh:PropertyShape ;
#     sh:name "has Contract Nature Type" ;
#     sh:node core-shape:at-voc-contract-nature-itemShape ;
#     sh:path :hasContractNatureType .
#
# core-shape:epo-ContractTerm-epo-hasEInvoicingPermission a sh:PropertyShape ;
#     sh:name "has E Invoicing Permission" ;
#     sh:node core-shape:at-voc-permission-itemShape ;
#     sh:path :hasEInvoicingPermission .
#
# core-shape:epo-ContractTerm-epo-hasReservedExecution a sh:PropertyShape ;
#     sh:class skos:Concept ;
#     sh:maxCount 1 ;
#     sh:name "has Reserved Execution" ;
#     sh:path :hasReservedExecution .
#
#
# Validation Report
# Conforms: True
#
# *** case 03: validation using restrictive shape for hasEInvoicingPermission with a concept belonging to at-voc:permission ***
# Data graph:
# @prefix at: <http://publications.europa.eu/ontology/authority/> .
# @prefix atold: <http://publications.europa.eu/resource/authority/> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix epd: <http://data.europa.eu/a4g/resource/> .
# @prefix epo: <http://data.europa.eu/a4g/ontology#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# epd:ContractTerm03 a epo:ContractTerm ;
#     epo:hasEInvoicingPermission <http://publications.europa.eu/resource/authority/permission/required> .
#
# <http://publications.europa.eu/resource/authority/permission/OP_DATPRO> a skos:Concept ;
#     at:authority-code "OP_DATPRO" ;
#     at:deprecated "true" ;
#     at:end.use "1952-07-24" ;
#     at:op-code "OP_DATPRO" ;
#     at:start.use "1952-07-23" ;
#     atold:op-code "OP_DATPRO" ;
#     dc:identifier "OP_DATPRO" ;
#     owl:deprecated true ;
#     skos:inScheme atold:permission ;
#     skos:prefLabel "Неокончателни данни"@bg,
#         "Předběžné údaje"@cs,
#         "Midlertidige data"@da,
#         "Vorläufige Daten"@de,
#         "Προσωρινά δεδομένα"@el,
#         "Provisional data"@en,
#         "Datos provisionales"@es,
#         "Esialgsed andmed"@et,
#         "Alustavat tiedot"@fi,
#         "Données provisoires"@fr,
#         "Sonraí sealadacha"@ga,
#         "Privremeni podaci"@hr,
#         "Ideiglenes adatok"@hu,
#         "Dati provvisori"@it,
#         "Laikinieji duomenys"@lt,
#         "Provizoriski dati"@lv,
#         "Dejta provviżorja"@mt,
#         "Voorlopige gegevens"@nl,
#         "Dane tymczasowe"@pl,
#         "Dados provisórios"@pt,
#         "Date provizorii"@ro,
#         "Predbežné údaje"@sk,
#         "Začasni podatki"@sl,
#         "Tillfälliga uppgifter"@sv ;
#     skos:topConceptOf atold:permission .
#
# <http://publications.europa.eu/resource/authority/permission/allowed> a skos:Concept ;
#     at:authority-code "allowed" ;
#     at:deprecated "false" ;
#     at:op-code "allowed" ;
#     at:start.use "2019-09-18" ;
#     atold:op-code "allowed" ;
#     dc:identifier "allowed" ;
#     skos:example "In eProcurement notices: Tenders can be submitted electronically; Tenders can include variants; Tenderers can submit eCatalogues; Electronic invoices are to be used"@en ;
#     skos:inScheme atold:permission ;
#     skos:prefLabel "Разрешено"@bg,
#         "Povolena"@cs,
#         "Tilladt"@da,
#         "Zulässig"@de,
#         "Επιτρέπεται"@el,
#         "Allowed"@en,
#         "Permitida"@es,
#         "Lubatud"@et,
#         "Sallittu"@fi,
#         "Autorisée"@fr,
#         "Ceadmhach"@ga,
#         "Dopušteno"@hr,
#         "Megengedett"@hu,
#         "Consentita"@it,
#         "Neprivalomos"@lt,
#         "Atļauts"@lv,
#         "Permessa"@mt,
#         "Toegestaan"@nl,
#         "Dozwolone"@pl,
#         "Permitido"@pt,
#         "Autorizată"@ro,
#         "Povolená"@sk,
#         "Dovoljeno"@sl,
#         "Tillåten"@sv ;
#     skos:scopeNote "The use case of 'Tenders can be submitted electronically' can only be used below thresholds as it is an obligation above threshold unless duly justified for all tenders."@en ;
#     skos:topConceptOf atold:permission .
#
# <http://publications.europa.eu/resource/authority/permission/not-allowed> a skos:Concept ;
#     at:authority-code "not-allowed" ;
#     at:deprecated "false" ;
#     at:op-code "not-allowed" ;
#     at:start.use "2019-09-18" ;
#     atold:op-code "not-allowed" ;
#     dc:identifier "not-allowed" ;
#     skos:example "In eProcurement notices: Tenders cannot be submitted electronically; Tenders cannot include variants; Tenderers cannot submit eCatalogues; Electronic invoices are not to be used"@en ;
#     skos:inScheme atold:permission ;
#     skos:prefLabel "Забранено"@bg,
#         "Nepovolena"@cs,
#         "Ikke tilladt"@da,
#         "Nicht zulässig"@de,
#         "Δεν επιτρέπεται"@el,
#         "Not allowed"@en,
#         "No autorizada"@es,
#         "Ei ole lubatud"@et,
#         "Ei sallittu"@fi,
#         "Non autorisée"@fr,
#         "Éigeantach"@ga,
#         "Nije dopušteno"@hr,
#         "Nem megengedett"@hu,
#         "Non consentita"@it,
#         "Draudžiamos"@lt,
#         "Nav atļauts"@lv,
#         "Mhux permessa"@mt,
#         "Niet toegestaan"@nl,
#         "Niedozwolone"@pl,
#         "Não autorizado"@pt,
#         "Nu este permisă"@ro,
#         "Nie je povolená"@sk,
#         "Ni dovoljeno"@sl,
#         "Ej tillåten"@sv ;
#     skos:topConceptOf atold:permission .
#
# <http://publications.europa.eu/resource/authority/permission/required> a skos:Concept ;
#     at:authority-code "required" ;
#     at:deprecated "false" ;
#     at:op-code "required" ;
#     at:start.use "2019-09-18" ;
#     atold:op-code "required" ;
#     dc:identifier "required" ;
#     skos:example "In eProcurement notices: Tenders must be submitted electronically; Tenders must include variants; Tenderers must submit eCatalogues; Electronic invoices must be used"@en ;
#     skos:inScheme atold:permission ;
#     skos:prefLabel "Задължително"@bg,
#         "Požadována"@cs,
#         "Påkrævet"@da,
#         "Erforderlich"@de,
#         "Υποχρεωτική"@el,
#         "Required"@en,
#         "Obligatoria"@es,
#         "Nõutav"@et,
#         "Pakollinen"@fi,
#         "Requise"@fr,
#         "Ní ceadmhach"@ga,
#         "Obvezno"@hr,
#         "Kötelező"@hu,
#         "Obbligatoria"@it,
#         "Privalomos"@lt,
#         "Prasīts"@lv,
#         "Meħtieġa"@mt,
#         "Vereist"@nl,
#         "Wymagane"@pl,
#         "Necessário"@pt,
#         "Obligatorie"@ro,
#         "Povinná"@sk,
#         "Obvezno"@sl,
#         "Krävs"@sv ;
#     skos:topConceptOf atold:permission .
#
# atold:permission a skos:ConceptScheme ;
#     rdfs:label "Permission"@en ;
#     at:prefLabel "Permission"@en ;
#     at:table.id "permission" ;
#     at:table.version.number "20240612-0" ;
#     owl:versionInfo "20240612-0" ;
#     skos:definition "This table provides the codes linked to the different values of permission and/or obligation. "@en ;
#     skos:hasTopConcept <http://publications.europa.eu/resource/authority/permission/OP_DATPRO>,
#         <http://publications.europa.eu/resource/authority/permission/allowed>,
#         <http://publications.europa.eu/resource/authority/permission/not-allowed>,
#         <http://publications.europa.eu/resource/authority/permission/required> ;
#     skos:prefLabel "Permission"@en .
#
#
# Shapes graph:
# @prefix : <http://data.europa.eu/a4g/ontology#> .
# @prefix at-voc: <http://publications.europa.eu/resource/authority/> .
# @prefix core-shape: <http://data.europa.eu/a4g/data-shape#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# core-shape:epo-ContractTerm a sh:NodeShape ;
#     rdfs:label "Contract Term" ;
#     rdfs:comment "Conditions and stipulations defining particularities of the Post Award Phase." ;
#     rdfs:isDefinedBy core-shape:core-shape ;
#     sh:property core-shape:epo-ContractTerm-epo-hasContractNatureType,
#         core-shape:epo-ContractTerm-epo-hasEInvoicingPermission,
#         core-shape:epo-ContractTerm-epo-hasReservedExecution ;
#     sh:targetClass :ContractTerm .
#
# core-shape:at-voc-contract-nature-itemShape a sh:NodeShape ;
#     sh:property [ sh:hasValue at-voc:contract-nature ;
#             sh:path skos:inScheme ] .
#
# core-shape:at-voc-permission-itemShape a sh:NodeShape ;
#     sh:property [ sh:hasValue at-voc:permission ;
#             sh:path skos:inScheme ] .
#
# core-shape:epo-ContractTerm-epo-hasContractNatureType a sh:PropertyShape ;
#     sh:name "has Contract Nature Type" ;
#     sh:node core-shape:at-voc-contract-nature-itemShape ;
#     sh:path :hasContractNatureType .
#
# core-shape:epo-ContractTerm-epo-hasEInvoicingPermission a sh:PropertyShape ;
#     sh:name "has E Invoicing Permission" ;
#     sh:node core-shape:at-voc-permission-itemShape ;
#     sh:path :hasEInvoicingPermission .
#
# core-shape:epo-ContractTerm-epo-hasReservedExecution a sh:PropertyShape ;
#     sh:class skos:Concept ;
#     sh:maxCount 1 ;
#     sh:name "has Reserved Execution" ;
#     sh:path :hasReservedExecution .
#
#
# Validation Report
# Conforms: True
#
# *** case 04: validation using restrictive shape for hasContractNatureType with a concept belonging to an arbitrary scheme fails ***
# Data graph:
# @prefix : <http://example.com/> .
# @prefix epd: <http://data.europa.eu/a4g/resource/> .
# @prefix epo: <http://data.europa.eu/a4g/ontology#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
#
# epd:ContractTerm04 a epo:ContractTerm ;
#     epo:hasContractNatureType :services .
#
# :contractNature a skos:ConceptScheme ;
#     skos:hasTopConcept :services ;
#     skos:prefLabel "contract nature"@en .
#
# :no a skos:Concept .
#
# :yes skos:prefLabel "yes" .
#
# :services a skos:Concept .
#
#
# Shapes graph:
# @prefix : <http://data.europa.eu/a4g/ontology#> .
# @prefix at-voc: <http://publications.europa.eu/resource/authority/> .
# @prefix core-shape: <http://data.europa.eu/a4g/data-shape#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# core-shape:epo-ContractTerm a sh:NodeShape ;
#     rdfs:label "Contract Term" ;
#     rdfs:comment "Conditions and stipulations defining particularities of the Post Award Phase." ;
#     rdfs:isDefinedBy core-shape:core-shape ;
#     sh:property core-shape:epo-ContractTerm-epo-hasContractNatureType,
#         core-shape:epo-ContractTerm-epo-hasEInvoicingPermission,
#         core-shape:epo-ContractTerm-epo-hasReservedExecution ;
#     sh:targetClass :ContractTerm .
#
# core-shape:at-voc-contract-nature-itemShape a sh:NodeShape ;
#     sh:property [ sh:hasValue at-voc:contract-nature ;
#             sh:path skos:inScheme ] .
#
# core-shape:at-voc-permission-itemShape a sh:NodeShape ;
#     sh:property [ sh:hasValue at-voc:permission ;
#             sh:path skos:inScheme ] .
#
# core-shape:epo-ContractTerm-epo-hasContractNatureType a sh:PropertyShape ;
#     sh:name "has Contract Nature Type" ;
#     sh:node core-shape:at-voc-contract-nature-itemShape ;
#     sh:path :hasContractNatureType .
#
# core-shape:epo-ContractTerm-epo-hasEInvoicingPermission a sh:PropertyShape ;
#     sh:name "has E Invoicing Permission" ;
#     sh:node core-shape:at-voc-permission-itemShape ;
#     sh:path :hasEInvoicingPermission .
#
# core-shape:epo-ContractTerm-epo-hasReservedExecution a sh:PropertyShape ;
#     sh:class skos:Concept ;
#     sh:maxCount 1 ;
#     sh:name "has Reserved Execution" ;
#     sh:path :hasReservedExecution .
#
#
# Validation Report
# Conforms: False
# Results (1):
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: core-shape:epo-ContractTerm-epo-hasContractNatureType
# 	Focus Node: epd:ContractTerm04
# 	Value Node: :services
# 	Result Path: :hasContractNatureType
# 	Message: Value does not conform to Shape core-shape:at-voc-contract-nature-itemShape. See details for more information.
# 	Details:
# 		Constraint Violation in HasValueConstraintComponent (http://www.w3.org/ns/shacl#HasValueConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:hasValue at-voc:contract-nature ; sh:path skos:inScheme ]
# 			Focus Node: :services
# 			Result Path: skos:inScheme
# 			Message: Node :services->skos:inScheme does not contain a value in the set: ['at-voc:contract-nature']
#
# *** case 05: validation using permissive shape for hasReservedExecution with an arbitrary resource fails ***
# Data graph:
# @prefix : <http://example.com/> .
# @prefix epd: <http://data.europa.eu/a4g/resource/> .
# @prefix epo: <http://data.europa.eu/a4g/ontology#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
#
# epd:ContractTerm05 a epo:ContractTerm ;
#     epo:hasReservedExecution <http://example/yes> .
#
# :contractNature a skos:ConceptScheme ;
#     skos:hasTopConcept :services ;
#     skos:prefLabel "contract nature"@en .
#
# :no a skos:Concept .
#
# :yes skos:prefLabel "yes" .
#
# :services a skos:Concept .
#
#
# Shapes graph:
# @prefix : <http://data.europa.eu/a4g/ontology#> .
# @prefix at-voc: <http://publications.europa.eu/resource/authority/> .
# @prefix core-shape: <http://data.europa.eu/a4g/data-shape#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# core-shape:epo-ContractTerm a sh:NodeShape ;
#     rdfs:label "Contract Term" ;
#     rdfs:comment "Conditions and stipulations defining particularities of the Post Award Phase." ;
#     rdfs:isDefinedBy core-shape:core-shape ;
#     sh:property core-shape:epo-ContractTerm-epo-hasContractNatureType,
#         core-shape:epo-ContractTerm-epo-hasEInvoicingPermission,
#         core-shape:epo-ContractTerm-epo-hasReservedExecution ;
#     sh:targetClass :ContractTerm .
#
# core-shape:at-voc-contract-nature-itemShape a sh:NodeShape ;
#     sh:property [ sh:hasValue at-voc:contract-nature ;
#             sh:path skos:inScheme ] .
#
# core-shape:at-voc-permission-itemShape a sh:NodeShape ;
#     sh:property [ sh:hasValue at-voc:permission ;
#             sh:path skos:inScheme ] .
#
# core-shape:epo-ContractTerm-epo-hasContractNatureType a sh:PropertyShape ;
#     sh:name "has Contract Nature Type" ;
#     sh:node core-shape:at-voc-contract-nature-itemShape ;
#     sh:path :hasContractNatureType .
#
# core-shape:epo-ContractTerm-epo-hasEInvoicingPermission a sh:PropertyShape ;
#     sh:name "has E Invoicing Permission" ;
#     sh:node core-shape:at-voc-permission-itemShape ;
#     sh:path :hasEInvoicingPermission .
#
# core-shape:epo-ContractTerm-epo-hasReservedExecution a sh:PropertyShape ;
#     sh:class skos:Concept ;
#     sh:maxCount 1 ;
#     sh:name "has Reserved Execution" ;
#     sh:path :hasReservedExecution .
#
#
# Validation Report
# Conforms: False
# Results (1):
# Constraint Violation in ClassConstraintComponent (http://www.w3.org/ns/shacl#ClassConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: core-shape:epo-ContractTerm-epo-hasReservedExecution
# 	Focus Node: epd:ContractTerm05
# 	Value Node: <http://example/yes>
# 	Result Path: :hasReservedExecution
# 	Message: Value does not have class skos:Concept
